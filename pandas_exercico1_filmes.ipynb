# %% [markdown]
# # <font color='dark'>**IMPORTANDO OS DADOS**</font>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/eduardoaugustopp/pandas-exercicio/main/Filmes_BD.csv'
pd.read_csv(url)
# Out:
#                                                                                                                                                                                                             Título do Filme;Ano;Diretor;Gênero;Sinopse;Avaliação;Prêmios
# O Poderoso Chefão;1972;Francis Ford Coppola;Dra...  liderada pelo patriarca Vito Corleone              e seu filho Michael                                que assume o controle do império do crime da f...                           incluindo Melhor Filme."
# O Poderoso Chefão II;1974;Francis Ford Coppola;...  entrelaçando suas histórias em uma narrativa é...  incluindo Melhor Filme."                          NaN                                                                                               NaN
# ...

# %%
pd.read_csv(url, sep=';')
# Out:
#                          Título do Filme   Ano  \
# 0                      O Poderoso Chefão  1972
# 1                   O Poderoso Chefão II  1974
# 2                  O Poderoso Chefão III  1990
# 3                   Os Bons Companheiros  1990
# 4                               Scarface  1983
# 5                          Os Intocáveis  1987
# 6                 Era uma Vez na América  1984
# 7                                Cassino  1995
# 8       Pulp Fiction: Tempo de Violência  1994
# 9                          Donnie Brasco  1997
# 10                  Gangues de Nova York  2002
# 11                      Infernal Affairs  2002
# 12                        Os Infiltrados  2006
# 13                            O Irlandês  2019
# 14  Bonnie & Clyde - Uma Rajada de Balas  1967
# 15                     Inimigos Públicos  2009
# 16                 O Gatilho Mais Rápido  1956
# 17               Estrada para a Perdição  2002
# 18                       Cães de Aluguel  1992
# ...

# %%
dados = pd.read_csv(url, sep=';')
dados
# Out:
#                          Título do Filme   Ano  \
# 0                      O Poderoso Chefão  1972
# 1                   O Poderoso Chefão II  1974
# 2                  O Poderoso Chefão III  1990
# 3                   Os Bons Companheiros  1990
# 4                               Scarface  1983
# 5                          Os Intocáveis  1987
# 6                 Era uma Vez na América  1984
# 7                                Cassino  1995
# 8       Pulp Fiction: Tempo de Violência  1994
# 9                          Donnie Brasco  1997
# 10                  Gangues de Nova York  2002
# 11                      Infernal Affairs  2002
# 12                        Os Infiltrados  2006
# 13                            O Irlandês  2019
# 14  Bonnie & Clyde - Uma Rajada de Balas  1967
# 15                     Inimigos Públicos  2009
# 16                 O Gatilho Mais Rápido  1956
# 17               Estrada para a Perdição  2002
# 18                       Cães de Aluguel  1992
# ...

# %%
dados.head(10)
# Out:
#                     Título do Filme   Ano               Diretor  \
# 0                 O Poderoso Chefão  1972  Francis Ford Coppola
# 1              O Poderoso Chefão II  1974  Francis Ford Coppola
# 2             O Poderoso Chefão III  1990  Francis Ford Coppola
# 3              Os Bons Companheiros  1990       Martin Scorsese
# 4                          Scarface  1983        Brian De Palma
# 5                     Os Intocáveis  1987        Brian De Palma
# 6            Era uma Vez na América  1984          Sergio Leone
# 7                           Cassino  1995       Martin Scorsese
# 8  Pulp Fiction: Tempo de Violência  1994     Quentin Tarantino
# 9                     Donnie Brasco  1997           Mike Newell
#
#           Gênero                                            Sinopse  \
# 0  Drama / Crime  A saga da família Corleone, liderada pelo patr...
# 1  Drama / Crime  Explora tanto a ascensão de Vito Corleone quan...
# ...

# %%
dados.tail()
# Out:
#          Título do Filme   Ano  \
# 24        A Última Noite  2002
# 25    O Império do Crime  2005
# 26       Os Imperdoáveis  1992
# 27  Entre Tiros e Vinhos  2005
# 28    Velozes e Furiosos  2001
#
#                                               Diretor            Gênero  \
# 24                                          Spike Lee     Drama / Crime
# 25                               Jean-François Richet     Drama / Crime
# 26                                     Clint Eastwood  Drama / Faroeste
# 27  Robert Rodriguez, Frank Miller, Quentin Tarantino  Crime / Suspense
# 28                                          Rob Cohen      Ação / Crime
#
#                                               Sinopse  Avaliação  \
# 24  Durante o apagão de Nova York em 1977, várias ...        6.4
# 25  A história real do criminoso Jacques Mesrine, ...        7.0
# 26  Um ex-pistoleiro é persuadido a realizar um úl...        8.2
# 27  Uma adaptação de histórias em quadrinhos noir,...        6.5
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # <font color='dark'>**Características gerais da base de dados**</font>

# %%
dados.shape
# Out:
# (29, 7)

# %%
dados.columns
# Out:
# Index(['Título do Filme', 'Ano', 'Diretor', 'Gênero', 'Sinopse', 'Avaliação',
#        'Prêmios'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Título do Filme  29 non-null     object
#  1   Ano              29 non-null     int64
#  2   Diretor          29 non-null     object
#  3   Gênero           29 non-null     object
#  4   Sinopse          29 non-null     object
#  5   Avaliação        29 non-null     float64
#  6   Prêmios          29 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.7+ KB

# %%
dados['Sinopse']
# Out:
# 0     A saga da família Corleone, liderada pelo patr...
# 1     Explora tanto a ascensão de Vito Corleone quan...
# 2     A tentativa de Michael Corleone de legitimar o...
# 3     A ascensão e queda de um grupo de gângsteres e...
# 4     A ascensão e queda de Tony Montana, um imigran...
# 5     A história real do agente do Tesouro Eliot Nes...
# 6     A vida de um grupo de amigos do Brooklyn, desd...
# 7     A ascensão e queda de um gerente de cassino e ...
# 8     Várias histórias interligadas explorando temas...
# 9     A história real de Joe Pistone, um agente do F...
# 10    A rivalidade entre gangues em Nova York durant...
# 11    Um policial infiltrado e um membro da gangue t...
# 12    Um policial disfarçado e um criminoso infiltra...
# 13    A vida de Frank Sheeran, um assassino da máfia...
# 14    A história real dos famosos criminosos Bonnie ...
# 15    A história real de John Dillinger e sua gangue...
# 16    A rivalidade entre dois irmãos pistoleiros dur...
# ...

# %%
dados[['Título do Filme', 'Avaliação']]
# Out:
#                          Título do Filme  Avaliação
# 0                      O Poderoso Chefão        9.2
# 1                   O Poderoso Chefão II        9.0
# 2                  O Poderoso Chefão III        7.6
# 3                   Os Bons Companheiros        8.7
# 4                               Scarface        8.3
# 5                          Os Intocáveis        7.9
# 6                 Era uma Vez na América        8.4
# 7                                Cassino        8.2
# 8       Pulp Fiction: Tempo de Violência        8.9
# 9                          Donnie Brasco        7.7
# 10                  Gangues de Nova York        7.5
# 11                      Infernal Affairs        8.1
# 12                        Os Infiltrados        8.5
# 13                            O Irlandês        7.8
# 14  Bonnie & Clyde - Uma Rajada de Balas        7.8
# 15                     Inimigos Públicos        7.0
# 16                 O Gatilho Mais Rápido        7.7
# ...

# %%
dados.head()
# Out:
#          Título do Filme   Ano               Diretor         Gênero  \
# 0      O Poderoso Chefão  1972  Francis Ford Coppola  Drama / Crime
# 1   O Poderoso Chefão II  1974  Francis Ford Coppola  Drama / Crime
# 2  O Poderoso Chefão III  1990  Francis Ford Coppola  Drama / Crime
# 3   Os Bons Companheiros  1990       Martin Scorsese  Drama / Crime
# 4               Scarface  1983        Brian De Palma  Drama / Crime
#
#                                              Sinopse  Avaliação  \
# 0  A saga da família Corleone, liderada pelo patr...        9.2
# 1  Explora tanto a ascensão de Vito Corleone quan...        9.0
# 2  A tentativa de Michael Corleone de legitimar o...        7.6
# 3  A ascensão e queda de um grupo de gângsteres e...        8.7
# 4  A ascensão e queda de Tony Montana, um imigran...        8.3
#
#                                             Prêmios
# 0  Vencedor de três Oscars, incluindo Melhor Filme.
# 1  Vencedor de seis Oscars, incluindo Melhor Filme.
# ...

# %% [markdown]
# # <font color='dark'>**Análise exploratória de dados**</font>

# %%
dados['Avaliação'].mean()
# Out:
# 7.827586206896552

# %%
df_preco_tipo = dados.groupby('Título do Filme')[['Avaliação']].mean().sort_values('Avaliação')

df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple');

# %% [markdown]
# # <font color='dark'>**REMOVENDO FILMES SEM PRÊMIOS**</font>

# %%
dados.Prêmios.unique()
# Out:
# array(['Vencedor de três Oscars, incluindo Melhor Filme.',
#        'Vencedor de seis Oscars, incluindo Melhor Filme.',
#        'Recebeu sete indicações ao Oscar.',
#        'Indicado ao Oscar de Melhor Diretor.', '-',
#        'Venceu o Oscar de Melhor Ator Coadjuvante (Sean Connery).',
#        'Indicações ao Oscar.',
#        'Venceu o Oscar de Melhor Roteiro Original.',
#        'Recebeu várias indicações ao Oscar.',
#        'Recebeu vários prêmios de cinema de Hong Kong.',
#        'Venceu quatro Oscars, incluindo Melhor Filme e Melhor Diretor.',
#        'Venceu dois Oscars, incluindo Melhor Atriz (Faye Dunaway).',
#        'Venceu o Oscar de Melhor Fotografia.',
#        'Recebeu vários prêmios de cinema independentes.',
#        'Vencedor do Grande Prêmio do Júri no Festival de Cannes.',
#        'Vencedor de cinco Oscars, incluindo Melhor Filme.',
#        'Vencedor de quatro Oscars, incluindo Melhor Filme.'], dtype=object)

# %%
sem_premios = ['-']

# %%
dados.query('@sem_premios in Prêmios')
# Out:
#                        Título do Filme   Ano  \
# 4                             Scarface  1983
# 6               Era uma Vez na América  1984
# 9                        Donnie Brasco  1997
# 15                   Inimigos Públicos  2009
# 16               O Gatilho Mais Rápido  1956
# 20  Scarface - A Vergonha de uma Nação  1932
# 23                       Bone Tomahawk  2015
# 24                      A Última Noite  2002
# 25                  O Império do Crime  2005
# 27                Entre Tiros e Vinhos  2005
# 28                  Velozes e Furiosos  2001
#
#                                               Diretor  \
# 4                                      Brian De Palma
# 6                                        Sergio Leone
# 9                                         Mike Newell
# 15                                       Michael Mann
# 16                                       John Sturges
# 20                                       Howard Hawks
# ...

# %%
dados.query('@sem_premios not in Prêmios')
# Out:
#                          Título do Filme   Ano               Diretor  \
# 0                      O Poderoso Chefão  1972  Francis Ford Coppola
# 1                   O Poderoso Chefão II  1974  Francis Ford Coppola
# 2                  O Poderoso Chefão III  1990  Francis Ford Coppola
# 3                   Os Bons Companheiros  1990       Martin Scorsese
# 5                          Os Intocáveis  1987        Brian De Palma
# 7                                Cassino  1995       Martin Scorsese
# 8       Pulp Fiction: Tempo de Violência  1994     Quentin Tarantino
# 10                  Gangues de Nova York  2002       Martin Scorsese
# 11                      Infernal Affairs  2002  Andrew Lau, Alan Mak
# 12                        Os Infiltrados  2006       Martin Scorsese
# 13                            O Irlandês  2019       Martin Scorsese
# 14  Bonnie & Clyde - Uma Rajada de Balas  1967           Arthur Penn
# 17               Estrada para a Perdição  2002            Sam Mendes
# ...

# %%
df = dados.query('@sem_premios not in Prêmios')

# %%
df.head()
# Out:
#          Título do Filme   Ano               Diretor         Gênero  \
# 0      O Poderoso Chefão  1972  Francis Ford Coppola  Drama / Crime
# 1   O Poderoso Chefão II  1974  Francis Ford Coppola  Drama / Crime
# 2  O Poderoso Chefão III  1990  Francis Ford Coppola  Drama / Crime
# 3   Os Bons Companheiros  1990       Martin Scorsese  Drama / Crime
# 5          Os Intocáveis  1987        Brian De Palma  Drama / Crime
#
#                                              Sinopse  Avaliação  \
# 0  A saga da família Corleone, liderada pelo patr...        9.2
# 1  Explora tanto a ascensão de Vito Corleone quan...        9.0
# 2  A tentativa de Michael Corleone de legitimar o...        7.6
# 3  A ascensão e queda de um grupo de gângsteres e...        8.7
# 5  A história real do agente do Tesouro Eliot Nes...        7.9
#
#                                              Prêmios
# 0   Vencedor de três Oscars, incluindo Melhor Filme.
# 1   Vencedor de seis Oscars, incluindo Melhor Filme.
# ...

# %%
df.Prêmios.unique()
# Out:
# array(['Vencedor de três Oscars, incluindo Melhor Filme.',
#        'Vencedor de seis Oscars, incluindo Melhor Filme.',
#        'Recebeu sete indicações ao Oscar.',
#        'Indicado ao Oscar de Melhor Diretor.',
#        'Venceu o Oscar de Melhor Ator Coadjuvante (Sean Connery).',
#        'Indicações ao Oscar.',
#        'Venceu o Oscar de Melhor Roteiro Original.',
#        'Recebeu várias indicações ao Oscar.',
#        'Recebeu vários prêmios de cinema de Hong Kong.',
#        'Venceu quatro Oscars, incluindo Melhor Filme e Melhor Diretor.',
#        'Venceu dois Oscars, incluindo Melhor Atriz (Faye Dunaway).',
#        'Venceu o Oscar de Melhor Fotografia.',
#        'Recebeu vários prêmios de cinema independentes.',
#        'Vencedor do Grande Prêmio do Júri no Festival de Cannes.',
#        'Vencedor de cinco Oscars, incluindo Melhor Filme.',
#        'Vencedor de quatro Oscars, incluindo Melhor Filme.'], dtype=object)

# %%
df_preco_tipo = df.groupby('Título do Filme')[['Avaliação']].mean().sort_values('Avaliação')

df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple');

# %%
df.Ano.unique()
# Out:
# array([1972, 1974, 1990, 1987, 1995, 1994, 2002, 2006, 2019, 1967, 1992,
#        2007, 2008, 1978])

# %%
df.Ano.value_counts(normalize=True)
# Out:
# Ano
# 2002    0.166667
# 1990    0.111111
# 1992    0.111111
# 1972    0.055556
# 1974    0.055556
# 1987    0.055556
# 1995    0.055556
# 1994    0.055556
# 2006    0.055556
# 2019    0.055556
# 1967    0.055556
# 2007    0.055556
# 2008    0.055556
# 1978    0.055556
# Name: proportion, dtype: float64

# %%
df.Ano.value_counts(normalize=True).to_frame().sort_values('Ano')
# Out:
#       proportion
# Ano
# 1967    0.055556
# 1972    0.055556
# 1974    0.055556
# 1978    0.055556
# 1987    0.055556
# 1990    0.111111
# 1992    0.111111
# 1994    0.055556
# 1995    0.055556
# 2002    0.166667
# 2006    0.055556
# 2007    0.055556
# 2008    0.055556
# 2019    0.055556

# %%
df_percentual_tipo = df.Ano.value_counts(normalize=True).to_frame().sort_values('Ano')

df_percentual_tipo.plot(kind='bar', figsize=(14, 10), color ='green',
                        xlabel = 'Tipos', ylabel = 'Percentual');

# %% [markdown]
# # <font color='dark'>**SELECIONANDO FILMES LANÇADOS NO ANO 2002**</font>

# %%
df.query('Ano == 2002')
# Out:
#             Título do Filme   Ano               Diretor         Gênero  \
# 10     Gangues de Nova York  2002       Martin Scorsese  Drama / Crime
# 11         Infernal Affairs  2002  Andrew Lau, Alan Mak  Drama / Crime
# 17  Estrada para a Perdição  2002            Sam Mendes  Drama / Crime
#
#                                               Sinopse  Avaliação  \
# 10  A rivalidade entre gangues em Nova York durant...        7.5
# 11  Um policial infiltrado e um membro da gangue t...        8.1
# 17  A jornada de um assassino de aluguel e seu fil...        7.7
#
#                                            Prêmios
# 10             Recebeu várias indicações ao Oscar.
# 11  Recebeu vários prêmios de cinema de Hong Kong.
# 17            Venceu o Oscar de Melhor Fotografia.

# %% [markdown]
# # <font color='dark'>**DADOS NULOS**</font>

# %%
df.isnull()
# Out:
#     Título do Filme    Ano  Diretor  Gênero  Sinopse  Avaliação  Prêmios
# 0             False  False    False   False    False      False    False
# 1             False  False    False   False    False      False    False
# 2             False  False    False   False    False      False    False
# 3             False  False    False   False    False      False    False
# 5             False  False    False   False    False      False    False
# 7             False  False    False   False    False      False    False
# 8             False  False    False   False    False      False    False
# 10            False  False    False   False    False      False    False
# 11            False  False    False   False    False      False    False
# 12            False  False    False   False    False      False    False
# 13            False  False    False   False    False      False    False
# 14            False  False    False   False    False      False    False
# ...

# %%
df.isnull().sum()
# Out:
# Título do Filme    0
# Ano                0
# Diretor            0
# Gênero             0
# Sinopse            0
# Avaliação          0
# Prêmios            0
# dtype: int64

# %% [markdown]
# # <font color='dark'>**REMOVENDO REGISTROS**</font>

# %%
df.query('Ano == 2002')
# Out:
#             Título do Filme   Ano               Diretor         Gênero  \
# 10     Gangues de Nova York  2002       Martin Scorsese  Drama / Crime
# 11         Infernal Affairs  2002  Andrew Lau, Alan Mak  Drama / Crime
# 17  Estrada para a Perdição  2002            Sam Mendes  Drama / Crime
#
#                                               Sinopse  Avaliação  \
# 10  A rivalidade entre gangues em Nova York durant...        7.5
# 11  Um policial infiltrado e um membro da gangue t...        8.1
# 17  A jornada de um assassino de aluguel e seu fil...        7.7
#
#                                            Prêmios
# 10             Recebeu várias indicações ao Oscar.
# 11  Recebeu vários prêmios de cinema de Hong Kong.
# 17            Venceu o Oscar de Melhor Fotografia.

# %%
df.query('Ano == 2002').index
# Out:
# Index([10, 11, 17], dtype='int64')

# %%
registros_a_remover = df.query('Ano == 2002').index

# %%
df.drop(registros_a_remover, axis=0, inplace=True)
# Out:
# <ipython-input-44-75551155bdd1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(registros_a_remover, axis=0, inplace=True)

# %%
df.query('Ano == 2002')
# Out:
# Empty DataFrame
# Columns: [Título do Filme, Ano, Diretor, Gênero, Sinopse, Avaliação, Prêmios]
# Index: []

# %%
df.head(10)
# Out:
#                          Título do Filme   Ano               Diretor  \
# 0                      O Poderoso Chefão  1972  Francis Ford Coppola
# 1                   O Poderoso Chefão II  1974  Francis Ford Coppola
# 2                  O Poderoso Chefão III  1990  Francis Ford Coppola
# 3                   Os Bons Companheiros  1990       Martin Scorsese
# 5                          Os Intocáveis  1987        Brian De Palma
# 7                                Cassino  1995       Martin Scorsese
# 8       Pulp Fiction: Tempo de Violência  1994     Quentin Tarantino
# 12                        Os Infiltrados  2006       Martin Scorsese
# 13                            O Irlandês  2019       Martin Scorsese
# 14  Bonnie & Clyde - Uma Rajada de Balas  1967           Arthur Penn
#
#            Gênero                                            Sinopse  \
# 0   Drama / Crime  A saga da família Corleone, liderada pelo patr...
# ...

# %%
df.Gênero.unique()
# Out:
# array(['Drama / Crime', 'Crime / Drama', 'Crime / Suspense',
#        'Drama / Faroeste'], dtype=object)

# %%
df.drop('Gênero', axis=1, inplace=True)
# Out:
# <ipython-input-49-d8263a4e59f9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Gênero', axis=1, inplace=True)

# %%
df.head()
# Out:
#          Título do Filme   Ano               Diretor  \
# 0      O Poderoso Chefão  1972  Francis Ford Coppola
# 1   O Poderoso Chefão II  1974  Francis Ford Coppola
# 2  O Poderoso Chefão III  1990  Francis Ford Coppola
# 3   Os Bons Companheiros  1990       Martin Scorsese
# 5          Os Intocáveis  1987        Brian De Palma
#
#                                              Sinopse  Avaliação  \
# 0  A saga da família Corleone, liderada pelo patr...        9.2
# 1  Explora tanto a ascensão de Vito Corleone quan...        9.0
# 2  A tentativa de Michael Corleone de legitimar o...        7.6
# 3  A ascensão e queda de um grupo de gângsteres e...        8.7
# 5  A história real do agente do Tesouro Eliot Nes...        7.9
#
#                                              Prêmios
# 0   Vencedor de três Oscars, incluindo Melhor Filme.
# 1   Vencedor de seis Oscars, incluindo Melhor Filme.
# 2                  Recebeu sete indicações ao Oscar.
# ...

# %% [markdown]
# # <font color='dark'>**FILTROS**</font>

# %%
df['Avaliação'] >= 8
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 5     False
# 7      True
# 8      True
# 12     True
# 13    False
# 14    False
# 18     True
# 19    False
# 21    False
# 22     True
# 26     True
# Name: Avaliação, dtype: bool

# %%
selecao1 = df['Avaliação'] >= 8
df[selecao1]
# Out:
#                      Título do Filme   Ano               Diretor  \
# 0                  O Poderoso Chefão  1972  Francis Ford Coppola
# 1               O Poderoso Chefão II  1974  Francis Ford Coppola
# 3               Os Bons Companheiros  1990       Martin Scorsese
# 7                            Cassino  1995       Martin Scorsese
# 8   Pulp Fiction: Tempo de Violência  1994     Quentin Tarantino
# 12                    Os Infiltrados  2006       Martin Scorsese
# 18                   Cães de Aluguel  1992     Quentin Tarantino
# 22                 O Franco-Atirador  1978        Michael Cimino
# 26                   Os Imperdoáveis  1992        Clint Eastwood
#
#                                               Sinopse  Avaliação  \
# 0   A saga da família Corleone, liderada pelo patr...        9.2
# 1   Explora tanto a ascensão de Vito Corleone quan...        9.0
# 3   A ascensão e queda de um grupo de gângsteres e...        8.7
# ...

# %%
selecao2 = df['Diretor'] == 'Francis Ford Coppola'
df[selecao2]
# Out:
#          Título do Filme   Ano               Diretor  \
# 0      O Poderoso Chefão  1972  Francis Ford Coppola
# 1   O Poderoso Chefão II  1974  Francis Ford Coppola
# 2  O Poderoso Chefão III  1990  Francis Ford Coppola
#
#                                              Sinopse  Avaliação  \
# 0  A saga da família Corleone, liderada pelo patr...        9.2
# 1  Explora tanto a ascensão de Vito Corleone quan...        9.0
# 2  A tentativa de Michael Corleone de legitimar o...        7.6
#
#                                             Prêmios
# 0  Vencedor de três Oscars, incluindo Melhor Filme.
# 1  Vencedor de seis Oscars, incluindo Melhor Filme.
# 2                 Recebeu sete indicações ao Oscar.

# %%
selecao_final = (selecao1) & (selecao2)
df[selecao_final]
# Out:
#         Título do Filme   Ano               Diretor  \
# 0     O Poderoso Chefão  1972  Francis Ford Coppola
# 1  O Poderoso Chefão II  1974  Francis Ford Coppola
#
#                                              Sinopse  Avaliação  \
# 0  A saga da família Corleone, liderada pelo patr...        9.2
# 1  Explora tanto a ascensão de Vito Corleone quan...        9.0
#
#                                             Prêmios
# 0  Vencedor de três Oscars, incluindo Melhor Filme.
# 1  Vencedor de seis Oscars, incluindo Melhor Filme.

# %%
df_1 = df[selecao_final]

# %%
selecao = (df['Ano'] >= 1984) & (df['Diretor'] == 'Martin Scorsese')
df[selecao]
# Out:
#          Título do Filme   Ano          Diretor  \
# 3   Os Bons Companheiros  1990  Martin Scorsese
# 7                Cassino  1995  Martin Scorsese
# 12        Os Infiltrados  2006  Martin Scorsese
# 13            O Irlandês  2019  Martin Scorsese
#
#                                               Sinopse  Avaliação  \
# 3   A ascensão e queda de um grupo de gângsteres e...        8.7
# 7   A ascensão e queda de um gerente de cassino e ...        8.2
# 12  Um policial disfarçado e um criminoso infiltra...        8.5
# 13  A vida de Frank Sheeran, um assassino da máfia...        7.8
#
#                                               Prêmios
# 3                Indicado ao Oscar de Melhor Diretor.
# 7                                Indicações ao Oscar.
# 12  Venceu quatro Oscars, incluindo Melhor Filme e...
# 13                Recebeu várias indicações ao Oscar.

# %%
df_2 = df[selecao]

# %% [markdown]
# # <font color='dark'>**CRIANDO COLUNA CATEGÓRICA**</font>

# %%
dados['Descricao'] = dados['Título do Filme'] + ' lançado em ' + dados['Ano'].astype(str) + ' com '  + \
                     dados['Avaliação'].astype(str) + ' de avaliação.'

# %%
dados.head()
# Out:
#          Título do Filme   Ano               Diretor         Gênero  \
# 0      O Poderoso Chefão  1972  Francis Ford Coppola  Drama / Crime
# 1   O Poderoso Chefão II  1974  Francis Ford Coppola  Drama / Crime
# 2  O Poderoso Chefão III  1990  Francis Ford Coppola  Drama / Crime
# 3   Os Bons Companheiros  1990       Martin Scorsese  Drama / Crime
# 4               Scarface  1983        Brian De Palma  Drama / Crime
#
#                                              Sinopse  Avaliação  \
# 0  A saga da família Corleone, liderada pelo patr...        9.2
# 1  Explora tanto a ascensão de Vito Corleone quan...        9.0
# 2  A tentativa de Michael Corleone de legitimar o...        7.6
# 3  A ascensão e queda de um grupo de gângsteres e...        8.7
# 4  A ascensão e queda de Tony Montana, um imigran...        8.3
#
#                                             Prêmios  \
# 0  Vencedor de três Oscars, incluindo Melhor Filme.
# 1  Vencedor de seis Oscars, incluindo Melhor Filme.
# ...

# %% [markdown]
# # <font color='dark'>**SALVAR**</font>

# %%
df.to_csv('dados_filmes.csv')

# %%
pd.read_csv('dados_filmes.csv')
# Out:
#     Unnamed: 0                       Título do Filme   Ano  \
# 0            0                     O Poderoso Chefão  1972
# 1            1                  O Poderoso Chefão II  1974
# 2            2                 O Poderoso Chefão III  1990
# 3            3                  Os Bons Companheiros  1990
# 4            5                         Os Intocáveis  1987
# 5            7                               Cassino  1995
# 6            8      Pulp Fiction: Tempo de Violência  1994
# 7           12                        Os Infiltrados  2006
# 8           13                            O Irlandês  2019
# 9           14  Bonnie & Clyde - Uma Rajada de Balas  1967
# 10          18                       Cães de Aluguel  1992
# 11          19                            O Gângster  2007
# 12          21                               Gomorra  2008
# 13          22                     O Franco-Atirador  1978
# 14          26                       Os Imperdoáveis  1992
#
# ...

# %% [markdown]
# # <font color='dark'>**TIRAR A COLUNA**</font>

# %%
df.to_csv('dados_filmes.csv', index=False)

# %%
pd.read_csv('dados_filmes.csv')
# Out:
#                          Título do Filme   Ano               Diretor  \
# 0                      O Poderoso Chefão  1972  Francis Ford Coppola
# 1                   O Poderoso Chefão II  1974  Francis Ford Coppola
# 2                  O Poderoso Chefão III  1990  Francis Ford Coppola
# 3                   Os Bons Companheiros  1990       Martin Scorsese
# 4                          Os Intocáveis  1987        Brian De Palma
# 5                                Cassino  1995       Martin Scorsese
# 6       Pulp Fiction: Tempo de Violência  1994     Quentin Tarantino
# 7                         Os Infiltrados  2006       Martin Scorsese
# 8                             O Irlandês  2019       Martin Scorsese
# 9   Bonnie & Clyde - Uma Rajada de Balas  1967           Arthur Penn
# 10                       Cães de Aluguel  1992     Quentin Tarantino
# 11                            O Gângster  2007          Ridley Scott
# 12                               Gomorra  2008        Matteo Garrone
# ...
